# %% [markdown]
# ## Loading/Exploring the data
#
# Load the iris.csv file into a pandas dataframe. Take a minute to familiarize yourself with the data.

# %% [markdown]
# ## Import Pandas
#
# Import the `pandas` library as `pd`

# %%
import pandas as pd

# %% [markdown]
# Read the `iris.csv` dataset into an object named `iris`

# %%
iris = pd.read_csv('iris.csv')
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# How many different species are in this dataset?

# %%
iris['species'].nunique()
# Out:
# 3

# %% [markdown]
# What are their names?

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# How many samples are there per species?
#
# <details><summary>Hint</summary>Use the <a href="http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html"><code>.value_counts()</code></a> method</details>

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
iris['species'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='species'>

# %% [markdown]
# ## Feature Engineering
#
# Create a new column called `'sepal_ratio'` which is equal to sepal width / sepal length

# %%
iris.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
iris['sepal_ratio'] = iris['sepal length (cm)'] / iris['sepal width (cm)']
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species  sepal_ratio
# 0       setosa     1.457143
# 1       setosa     1.633333
# 2       setosa     1.468750
# 3       setosa     1.483871
# 4       setosa     1.388889
# ..         ...          ...
# 145  virginica     2.233333
# 146  virginica     2.520000
# 147  virginica     2.166667
# 148  virginica     1.823529
# 149  virginica     1.966667
#
# [150 rows x 6 columns]

# %% [markdown]
# Create a similar column called `'petal_ratio'`: petal width / petal length

# %%
iris['petal_ratio'] = iris['petal length (cm)'] / iris['petal width (cm)']
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species  sepal_ratio  petal_ratio
# 0       setosa     1.457143     7.000000
# 1       setosa     1.633333     7.000000
# 2       setosa     1.468750     6.500000
# 3       setosa     1.483871     7.500000
# 4       setosa     1.388889     7.000000
# ..         ...          ...          ...
# 145  virginica     2.233333     2.260870
# 146  virginica     2.520000     2.631579
# 147  virginica     2.166667     2.600000
# 148  virginica     1.823529     2.347826
# 149  virginica     1.966667     2.833333
#
# [150 rows x 7 columns]

# %% [markdown]
# Create 4 columns that correspond to `sepal length (cm)`, `sepal width (cm)`, `petal length (cm)`, and `petal width (cm)`, only in inches.

# %%
# Conversion factor from centimeters to inches
cm_to_inch = 0.393701

# Create new columns for measurements in inches
iris['sepal length (in)'] = iris['sepal length (cm)'] * cm_to_inch
iris['sepal width (in)'] = iris['sepal width (cm)'] * cm_to_inch
iris['petal length (in)'] = iris['petal length (cm)'] * cm_to_inch
iris['petal width (in)'] = iris['petal width (cm)'] * cm_to_inch

# Display the updated DataFrame
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species  sepal_ratio  petal_ratio  sepal length (in)  sepal width (in)  \
# 0       setosa     1.457143     7.000000           2.007875          1.377954
# 1       setosa     1.633333     7.000000           1.929135          1.181103
# 2       setosa     1.468750     6.500000           1.850395          1.259843
# 3       setosa     1.483871     7.500000           1.811025          1.220473
# 4       setosa     1.388889     7.000000           1.968505          1.417324
# ..         ...          ...          ...                ...               ...
# 145  virginica     2.233333     2.260870           2.637797          1.181103
# 146  virginica     2.520000     2.631579           2.480316          0.984253
# 147  virginica     2.166667     2.600000           2.559057          1.181103
# 148  virginica     1.823529     2.347826           2.440946          1.338583
# 149  virginica     1.966667     2.833333           2.322836          1.181103
#
#      petal length (in)  petal width (in)
# 0             0.551181          0.078740
# 1             0.551181          0.078740
# 2             0.511811          0.078740
# 3             0.590552          0.078740
# 4             0.551181          0.078740
# ..                 ...               ...
# 145           2.047245          0.905512
# 146           1.968505          0.748032
# 147           2.047245          0.787402
# 148           2.125985          0.905512
# 149           2.007875          0.708662
#
# [150 rows x 11 columns]

# %% [markdown]
# ## Apply
#
# Create a column called `'encoded_species'`:
# - 0 for setosa
# - 1 for versicolor
# - 2 for virginica
#
#
# Hint 1
# Create a dictionary using the species as keys and the numbers 0-2 for values
#
#
# Hint 2
#     Use the dictionary in hint 1 with the <code>.apply()</code> method to create the new column

# %%
encoded_species = {'setosa': 0, 'versicolor': 1, 'virginica': 2}
iris['encoded_species'] = iris['species'].map(encoded_species)
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species  sepal_ratio  petal_ratio  sepal length (in)  sepal width (in)  \
# 0       setosa     1.457143     7.000000           2.007875          1.377954
# 1       setosa     1.633333     7.000000           1.929135          1.181103
# 2       setosa     1.468750     6.500000           1.850395          1.259843
# 3       setosa     1.483871     7.500000           1.811025          1.220473
# 4       setosa     1.388889     7.000000           1.968505          1.417324
# ..         ...          ...          ...                ...               ...
# 145  virginica     2.233333     2.260870           2.637797          1.181103
# 146  virginica     2.520000     2.631579           2.480316          0.984253
# 147  virginica     2.166667     2.600000           2.559057          1.181103
# 148  virginica     1.823529     2.347826           2.440946          1.338583
# 149  virginica     1.966667     2.833333           2.322836          1.181103
#
#      petal length (in)  petal width (in)  encoded_species
# 0             0.551181          0.078740                0
# 1             0.551181          0.078740                0
# 2             0.511811          0.078740                0
# 3             0.590552          0.078740                0
# 4             0.551181          0.078740                0
# ..                 ...               ...              ...
# 145           2.047245          0.905512                2
# 146           1.968505          0.748032                2
# 147           2.047245          0.787402                2
# 148           2.125985          0.905512                2
# 149           2.007875          0.708662                2
#
# [150 rows x 12 columns]

# %% [markdown]
# ## March Madness
#
# Let's change up the dataset to something different than flowers: March Madness!
#
# Read in the dataset `ncaa-seeds.csv` to an object named `seeds`.
#
# This dataframe simulates the games that will occur in the first round of the [NCAA basketball tournament](http://www.sportingnews.com/au/ncaa-basketball/news/ncaa-tournament-2017-march-madness-bracket-schedule-matchups-print-a-bracket/1r6cau9sb1xj4131zzhay2dj5g). In the first row, you should see the following:
#
# | team_seed | opponent_seed |
# |-----------|---------------|
# | 01N       | 16N           |

# %%
seeds = pd.read_csv('ncaa-seeds.csv')
seeds
# Out:
#    team_seed opponent_seed
# 0        01N           16N
# 1        02N           15N
# 2        03N           14N
# 3        04N           13N
# 4        05N           12N
# 5        06N           11N
# 6        07N           10N
# 7        08N           09N
# 8        01S           16S
# 9        02S           15S
# 10       03S           14S
# 11       04S           13S
# 12       05S           12S
# 13       06S           11S
# 14       07S           10S
# 15       08S           09S
# 16       01E           16E
# 17       02E           15E
# 18       03E           14E
# 19       04E           13E
# 20       05E           12E
# 21       06E           11E
# 22       07E           10E
# 23       08E           09E
# 24       01W           16W
# 25       02W           15W
# 26       03W           14W
# 27       04W           13W
# 28       05W           12W
# 29       06W           11W
# 30       07W           10W
# 31       08W           09W

# %% [markdown]
# For team_seed, the 01 is their seed, and N is their division (North). This row is saying the 1st seed in the north division will play the 16th seed (same division).
#
# Using the `.apply()` method, create the following new columns:
# - `team_division`
# - `opponent_division`
#
# The first row of your result should look as follows:
#
# | team_seed | opponent_seed | team_division | opponent_division |
# |-----------|---------------|---------------|-------------------|
# | 01N       | 16N           | N             | N                 |

# %%
seeds['team_division'] = seeds.apply(lambda row: row['team_seed'][-1], axis=1)
seeds['opponenet_division'] = seeds.apply(lambda row: row['opponent_seed'][-1], axis=1)

# %%
seeds.head()
# Out:
#   team_seed opponent_seed team_division opponenet_division
# 0       01N           16N             N                  N
# 1       02N           15N             N                  N
# 2       03N           14N             N                  N
# 3       04N           13N             N                  N
# 4       05N           12N             N                  N

# %% [markdown]
# Now that you have the divisions, change the `team_seed` and `opponent_seed` columns to just be the numbers.
#
# The first row of your result should look as follows:
#
# | team_seed | opponent_seed | team_division | opponent_division |
# |-----------|---------------|---------------|-------------------|
# | 1         | 16            | N             | N                 |

# %%
seeds['team_seed'] = seeds['team_seed'].apply(lambda x: int(x[:-1]))
seeds['opponent_seed'] = seeds['opponent_seed'].apply(lambda x: int(x[:-1]))

seeds.head()
# Out:
#    team_seed  opponent_seed team_division opponenet_division
# 0          1             16             N                  N
# 1          2             15             N                  N
# 2          3             14             N                  N
# 3          4             13             N                  N
# 4          5             12             N                  N

# %% [markdown]
# Create a new column called seed_delta, which is the difference between the team's seed and their opponent's.
#
# The first row of your result should look as follows:
#
# | team_seed | opponent_seed | team_division | opponent_division | seed_delta |
# |-----------|---------------|---------------|-------------------|------------|
# | 1         | 16            | N             | N                 | -15        |
#
# <br>
# <details><summary>Did you get an error?</summary>
# team_seed and opponent_seed need to be numerical columns in order for you to perform mathematical operations on them.
# </details>

# %%
seeds['seed_delta'] = seeds['team_seed'] - seeds['opponent_seed']
seeds.head()
# Out:
#    team_seed  opponent_seed team_division opponenet_division  seed_delta
# 0          1             16             N                  N         -15
# 1          2             15             N                  N         -13
# 2          3             14             N                  N         -11
# 3          4             13             N                  N          -9
# 4          5             12             N                  N          -7
